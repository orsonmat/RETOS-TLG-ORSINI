# %% [markdown]
# # RETO VACUNAS EN EL MUNDO

# %% [markdown]
# a. Extraer la información del archivo.

# %%
import numpy as np
import pandas as pd

vacunacion = pd.read_csv('/content/country_vaccinations.csv')

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
vacunacion['date']= pd.to_datetime(vacunacion['date'])
vacunacion.info()
vacunacion.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 9.9+ MB
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
vacunas_pais= vacunacion[['daily_vaccinations','vaccines']].groupby('vaccines').sum()
print('Total de vacacunas por pais:',vacunas_pais)
# Out:
# Total de vacacunas por pais:                                                     daily_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...           9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...         201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...          37861146.0
# Abdala, Soberana Plus, Soberana02                           33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...         146357015.0
# ...                                                                ...
# Pfizer/BioNTech, Sinovac, Turkovac                         147484328.0
# Pfizer/BioNTech, Sputnik V                                     68643.0
# QazVac, Sinopharm/Beijing, Sputnik V                        20891256.0
# Sinopharm/Beijing                                             893824.0
# Sinopharm/Beijing, Sputnik V                                14398697.0
#
# [84 rows x 1 columns]

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
vacunacion_total =  vacunacion['daily_vaccinations'].sum()
print('La cantidad total de vacunas aplicadas en todo el mundo es de:',
      "{:,}".format(vacunacion_total))
# Out:
# La cantidad total de vacunas aplicadas en todo el mundo es de: 11,320,239,871.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
total_paises = vacunacion['country'].nunique()
avg_vac_pais= vacunacion_total/total_paises
print('Total paises que han aplicado vacunas:',total_paises)
print('En promedio la cantidad de vacanas que cada país ha aplicado es de:', "{0:,.2f}".format(avg_vac_pais))
# Out:
# Total paises que han aplicado vacunas: 223
# En promedio la cantidad de vacanas que cada país ha aplicado es de: 50,763,407.49

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
vac_29ene2021 = vacunacion[vacunacion['date'] == "29-01-2021"]
total_vac_29ene2021= vac_29ene2021['daily_vaccinations'].sum()
print('El día 29 de enero del 2021 se registraron un total de:', "{0:,}".format(total_vac_29ene2021), 'vacunaciones a nivel mundial')
vac_29ene2021
# Out:
# El día 29 de enero del 2021 se registraron un total de: 4,884,052.0 vacunaciones a nivel mundial
#                         country  iso_code       date  total_vaccinations  \
# 413                     Albania       ALB 2021-01-29                 NaN
# 833                     Algeria       DZA 2021-01-29                 0.0
# 1242                    Andorra       AND 2021-01-29                 NaN
# 2879                  Argentina       ARG 2021-01-29            379788.0
# 4441                    Austria       AUT 2021-01-29            264816.0
# ...                         ...       ...        ...                 ...
# 80132  Turks and Caicos Islands       TCA 2021-01-29                 NaN
# 81492      United Arab Emirates       ARE 2021-01-29           3006601.0
# 81936            United Kingdom       GBR 2021-01-29           8859372.0
# 82407             United States       USA 2021-01-29          36256855.0
# 84650                     Wales  OWID_WLS 2021-01-29            378950.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 413                  NaN                      NaN                     NaN
# 833                  0.0                      NaN                     NaN
# 1242                 NaN                      NaN                     NaN
# 2879            286984.0                  92778.0                 23493.0
# 4441            242173.0                  22637.0                     NaN
# ...                  ...                      ...                     ...
# 80132                NaN                      NaN                     NaN
# 81492                NaN                      NaN                137956.0
# 81936          8378940.0                 480432.0                489934.0
# 82407         28607556.0                6984964.0               1914257.0
# 84650           378200.0                    750.0                 15980.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 413                   0.0                             NaN
# 833                   NaN                            0.00
# 1242                 66.0                             NaN
# 2879              11558.0                            0.83
# 4441               7047.0                            2.93
# ...                   ...                             ...
# 80132               312.0                             NaN
# 81492             95361.0                           30.09
# 81936            361343.0                           12.99
# 82407           1449389.0                           10.92
# 84650             19705.0                           11.95
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 413                              NaN                                  NaN
# 833                             0.00                                  NaN
# 1242                             NaN                                  NaN
# 2879                            0.63                                 0.20
# 4441                            2.68                                 0.25
# ...                              ...                                  ...
# 80132                            NaN                                  NaN
# 81492                            NaN                                  NaN
# 81936                          12.28                                 0.70
# 82407                           8.62                                 2.10
# 84650                          11.93                                 0.02
#
#        daily_vaccinations_per_million  \
# 413                               0.0
# 833                               NaN
# 1242                            853.0
# 2879                            253.0
# 4441                            779.0
# ...                               ...
# 80132                          7954.0
# 81492                          9545.0
# 81936                          5298.0
# 82407                          4366.0
# 84650                          6216.0
#
#                                                 vaccines  \
# 413    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 833    Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 1242        Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 2879   CanSino, Moderna, Oxford/AstraZeneca, Pfizer/B...
# 4441   Johnson&Johnson, Moderna, Novavax, Oxford/Astr...
# ...                                                  ...
# 80132                                    Pfizer/BioNTech
# 81492  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 81936       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 82407          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 84650       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                              source_name  \
# 413                                   Ministry of Health
# 833                            World Health Organization
# 1242                           World Health Organization
# 2879                                  Ministry of Health
# 4441                                  Ministry of Health
# ...                                                  ...
# 80132                          World Health Organization
# 81492  National Emergency Crisis and Disaster Managem...
# 81936                   Government of the United Kingdom
# 82407         Centers for Disease Control and Prevention
# 84650                   Government of the United Kingdom
#
#                                           source_website
# 413    https://shendetesia.gov.al/vaksinimi-anticovid...
# 833                             https://covid19.who.int/
# 1242                            https://covid19.who.int/
# 2879                          https://covidstats.com.ar/
# 4441   https://www.ecdc.europa.eu/en/publications-dat...
# ...                                                  ...
# 80132                           https://covid19.who.int/
# 81492  https://fcsc.gov.ae/en-us/Pages/Covid19/UAE-Co...
# 81936  https://coronavirus.data.gov.uk/details/vaccin...
# 82407  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 84650  https://coronavirus.data.gov.uk/details/vaccin...
#
# [83 rows x 15 columns]

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = vacunacion.copy()
conDiferencias['diferencias'] = conDiferencias['daily_vaccinations'].fillna(0)-conDiferencias['daily_vaccinations_raw'].fillna(0) # se cambian los valores nulos con 0 para eviatar que resta sea nulo
conDiferencias.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  diferencias
# 0  World Health Organization  https://covid19.who.int/          0.0
# 1  World Health Organization  https://covid19.who.int/       1367.0
# 2  World Health Organization  https://covid19.who.int/       1367.0
# 3  World Health Organization  https://covid19.who.int/       1367.0
# 4  World Health Organization  https://covid19.who.int/       1367.0

# %% [markdown]
# h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
t_trasncurrido = vacunacion['date'].max() - vacunacion['date'].min()
print("Han transcurrido:", t_trasncurrido, 'desde al inicio de la vacunación')
# Out:
# Han transcurrido: 482 days 00:00:00 desde al inicio de la vacunación

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

# %%
conCantidad = vacunacion.copy()
conCantidad['canVac'] = conCantidad['vaccines'].str.split(",").str.len()
conCantidad.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  canVac
# 0  World Health Organization  https://covid19.who.int/       4
# 1  World Health Organization  https://covid19.who.int/       4
# 2  World Health Organization  https://covid19.who.int/       4
# 3  World Health Organization  https://covid19.who.int/       4
# 4  World Health Organization  https://covid19.who.int/       4

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = vacunacion[vacunacion['date'] < "20-12-2020"]
antes20
# Out:
#              country iso_code       date  total_vaccinations  \
# 13403         Canada      CAN 2020-12-14                 5.0
# 13404         Canada      CAN 2020-12-15               727.0
# 13405         Canada      CAN 2020-12-16              3025.0
# 13406         Canada      CAN 2020-12-17              7279.0
# 13407         Canada      CAN 2020-12-18             11296.0
# ...              ...      ...        ...                 ...
# 82362  United States      USA 2020-12-15             84638.0
# 82363  United States      USA 2020-12-16            244549.0
# 82364  United States      USA 2020-12-17            517161.0
# 82365  United States      USA 2020-12-18            933551.0
# 82366  United States      USA 2020-12-19           1115437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 13403                5.0                      NaN                     NaN
# 13404              727.0                      NaN                   722.0
# 13405             3025.0                      NaN                  2298.0
# 13406             7279.0                      NaN                  4254.0
# 13407            11296.0                      NaN                  4017.0
# ...                  ...                      ...                     ...
# 82362            76984.0                   6281.0                 49771.0
# 82363           231496.0                   6757.0                159911.0
# 82364           496980.0                   7507.0                272612.0
# 82365           904656.0                   8718.0                416390.0
# 82366          1082608.0                   9778.0                181886.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 13403                 NaN                            0.00
# 13404               722.0                            0.00
# 13405              1510.0                            0.01
# 13406              2425.0                            0.02
# 13407              2823.0                            0.03
# ...                   ...                             ...
# 82362             27175.0                            0.03
# 82363             71420.0                            0.07
# 82364            121718.0                            0.16
# 82365            180653.0                            0.28
# 82366            180858.0                            0.34
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 13403                           0.00                                  NaN
# 13404                           0.00                                  NaN
# 13405                           0.01                                  NaN
# 13406                           0.02                                  NaN
# 13407                           0.03                                  NaN
# ...                              ...                                  ...
# 82362                           0.02                                  0.0
# 82363                           0.07                                  0.0
# 82364                           0.15                                  0.0
# 82365                           0.27                                  0.0
# 82366                           0.33                                  0.0
#
#        daily_vaccinations_per_million  \
# 13403                             NaN
# 13404                            19.0
# 13405                            40.0
# 13406                            64.0
# 13407                            74.0
# ...                               ...
# 82362                            82.0
# 82363                           215.0
# 82364                           367.0
# 82365                           544.0
# 82366                           545.0
#
#                                                 vaccines  \
# 13403  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13404  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13405  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13406  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13407  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# ...                                                  ...
# 82362          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82363          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82364          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82365          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82366          Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                              source_name  \
# 13403  Official data from provinces via covid19tracke...
# 13404  Official data from provinces via covid19tracke...
# 13405  Official data from provinces via covid19tracke...
# 13406  Official data from provinces via covid19tracke...
# 13407  Official data from provinces via covid19tracke...
# ...                                                  ...
# 82362         Centers for Disease Control and Prevention
# 82363         Centers for Disease Control and Prevention
# 82364         Centers for Disease Control and Prevention
# 82365         Centers for Disease Control and Prevention
# 82366         Centers for Disease Control and Prevention
#
#                                           source_website
# 13403  https://covid19tracker.ca/vaccinationtracker.html
# 13404  https://covid19tracker.ca/vaccinationtracker.html
# 13405  https://covid19tracker.ca/vaccinationtracker.html
# 13406  https://covid19tracker.ca/vaccinationtracker.html
# 13407  https://covid19tracker.ca/vaccinationtracker.html
# ...                                                  ...
# 82362  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82363  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82364  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82365  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82366  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
#
# [70 rows x 15 columns]

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = vacunacion[vacunacion['vaccines'].str.contains('Pfizer',case=False)]
pfizer
# Out:
#            country  iso_code       date  total_vaccinations  \
# 0      Afghanistan       AFG 2021-02-22                 0.0
# 1      Afghanistan       AFG 2021-02-23                 NaN
# 2      Afghanistan       AFG 2021-02-24                 NaN
# 3      Afghanistan       AFG 2021-02-25                 NaN
# 4      Afghanistan       AFG 2021-02-26                 NaN
# ...            ...       ...        ...                 ...
# 85069        Wales  OWID_WLS 2022-03-24           6921195.0
# 85070        Wales  OWID_WLS 2022-03-25           6923298.0
# 85071        Wales  OWID_WLS 2022-03-26           6923706.0
# 85072        Wales  OWID_WLS 2022-03-27           6925183.0
# 85073        Wales  OWID_WLS 2022-03-28           6927437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 85069          2526832.0                2397677.0                  1756.0
# 85070          2527100.0                2398097.0                  2103.0
# 85071          2527184.0                2398322.0                   408.0
# 85072          2528051.0                2398676.0                  1477.0
# 85073          2528664.0                2399341.0                  2254.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 85069              1705.0                          218.33
# 85070              1667.0                          218.40
# 85071              1519.0                          218.41
# 85072              1505.0                          218.46
# 85073              1609.0                          218.53
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 85069                          79.71                                75.64
# 85070                          79.72                                75.65
# 85071                          79.72                                75.66
# 85072                          79.75                                75.67
# 85073                          79.77                                75.69
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                34.0
# 2                                34.0
# 3                                34.0
# 4                                34.0
# ...                               ...
# 85069                           538.0
# 85070                           526.0
# 85071                           479.0
# 85072                           475.0
# 85073                           508.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 85069       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85070       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85071       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85072       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85073       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                             source_name  \
# 0             World Health Organization
# 1             World Health Organization
# 2             World Health Organization
# 3             World Health Organization
# 4             World Health Organization
# ...                                 ...
# 85069  Government of the United Kingdom
# 85070  Government of the United Kingdom
# 85071  Government of the United Kingdom
# 85072  Government of the United Kingdom
# 85073  Government of the United Kingdom
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 85069  https://coronavirus.data.gov.uk/details/vaccin...
# 85070  https://coronavirus.data.gov.uk/details/vaccin...
# 85071  https://coronavirus.data.gov.uk/details/vaccin...
# 85072  https://coronavirus.data.gov.uk/details/vaccin...
# 85073  https://coronavirus.data.gov.uk/details/vaccin...
#
# [64193 rows x 15 columns]

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
with pd.ExcelWriter("/content/resultadosReto.xlsx") as writer:

    conDiferencias.to_excel(writer, sheet_name="conDiferencias")
    conCantidad.to_excel(writer, sheet_name="conCantidad")
    antes20.to_excel(writer, sheet_name="antes20")
    pfizer.to_excel(writer, sheet_name="pfizer")
